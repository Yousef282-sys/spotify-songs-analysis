# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("spotify_songs_dataset.csv")

# %%
df.head()
# Out:
#   song_id               song_title             artist              album  \
# 0  SP0001  Space executive series.       Sydney Clark              What.
# 1  SP0002     Price last painting.  Connor Peters DDS   Nature politics.
# 2  SP0003                   Piece.         Anna Keith             Visit.
# 3  SP0004     Power industry your.    Zachary Simpson  Behavior evening.
# 4  SP0005      Food animal second.  Christopher Mcgee             Front.
#
#         genre release_date  duration  popularity    stream language  \
# 0  Electronic   1997-11-08     282.0          42  35055874  English
# 1  Electronic   2015-05-10     127.0          50   9249527  English
# 2         Pop   2024-07-08       NaN          10  76669110  English
# 3     Hip-Hop   2022-08-15     214.0          86  34732016  English
# 4         Pop   2023-03-05     273.0          63  96649372  English
#
#   explicit_content            label       composer           producer  \
# ...

# %%
df
# Out:
#        song_id               song_title             artist              album  \
# 0       SP0001  Space executive series.       Sydney Clark              What.
# 1       SP0002     Price last painting.  Connor Peters DDS   Nature politics.
# 2       SP0003                   Piece.         Anna Keith             Visit.
# 3       SP0004     Power industry your.    Zachary Simpson  Behavior evening.
# 4       SP0005      Food animal second.  Christopher Mcgee             Front.
# ...        ...                      ...                ...                ...
# 49995  SP49996      Event push do body.   Shelley Robinson         Wrong cup.
# 49996  SP49997      Share clearly role.   Jennifer Kennedy     That actually.
# 49997  SP49998      Wonder type simply.       Hailey Walsh    South Democrat.
# 49998  SP49999                 Company.       Leah Coleman             Front.
# 49999  SP50000              Woman plan.       Daniel Brown             Three.
#
# ...

# %%
#معرفة النوع
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   song_id           50000 non-null  object
#  1   song_title        50000 non-null  object
#  2   artist            50000 non-null  object
#  3   album             50000 non-null  object
#  4   genre             50000 non-null  object
#  5   release_date      50000 non-null  object
#  6   duration          45000 non-null  float64
#  7   popularity        50000 non-null  int64
#  8   stream            50000 non-null  int64
#  9   language          47500 non-null  object
#  10  explicit_content  50000 non-null  object
#  11  label             50000 non-null  object
#  12  composer          50000 non-null  object
#  13  producer          50000 non-null  object
#  14  collaboration     15000 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 5.7+ MB

# %%
#المفقود
df.isnull().sum()
# Out:
# song_id                 0
# song_title              0
# artist                  0
# album                   0
# genre                   0
# release_date            0
# duration             5000
# popularity              0
# stream                  0
# language             2500
# explicit_content        0
# label                   0
# composer                0
# producer                0
# collaboration       35000
# dtype: int64

# %%
df.describe()
# Out:
#            duration    popularity        stream
# count  45000.000000  50000.000000  5.000000e+04
# mean     239.659178     50.783440  5.019183e+07
# std       50.136727     28.948749  2.893624e+07
# min       33.000000      1.000000  1.899000e+03
# 25%      206.000000     26.000000  2.523311e+07
# 50%      240.000000     51.000000  5.042169e+07
# 75%      273.000000     76.000000  7.519064e+07
# max      433.000000    100.000000  9.999913e+07

# %%
#النوع المشهور
top_gen= df['genre'].value_counts()

# %%
top_gen
# Out:
# genre
# Electronic    12568
# Pop           12534
# Hip-Hop       12298
# Folk           2559
# Classical      2542
# Country        2511
# Jazz           2504
# R&B            1513
# Reggae          971
# Name: count, dtype: int64

# %%
#اكتر اغاني للفنانين
top_art=df['artist'].value_counts()

# %%
top_art
# Out:
# artist
# Michael Smith          23
# Michael Johnson        20
# John Smith             20
# David Jones            19
# Christopher Johnson    17
#                        ..
# Harry Duarte            1
# Cassandra Edwards       1
# Kelli Garcia            1
# Jenna Martinez          1
# Leah Coleman            1
# Name: count, Length: 40182, dtype: int64

# %%
#اكتر اغاني مشهورة
top_populare=df.sort_values(by='popularity',ascending= False)

# %%
top_populare
# Out:
#        song_id                        song_title             artist  \
# 3778    SP3779                Clear range house.        Paul Fisher
# 8043    SP8044                       Guess huge.  Stephanie Vasquez
# 32632  SP32633                      Seek strong.      Taylor Harris
# 32634  SP32635  School provide crime investment.      Anthony Meyer
# 34220  SP34221                           Detail.     Kristen Mendez
# ...        ...                               ...                ...
# 5989    SP5990    Technology necessary director.       Aaron Baxter
# 16297  SP16298          Environment ever reason.       Hunter White
# 32274  SP32275            Sometimes give record.  Jonathan Andersen
# 19456  SP19457            Main similar military.    Colleen Johnson
# 40723  SP40724                        Size walk.      Laurie Nelson
#
#                     album       genre release_date  duration  popularity  \
# 3778   Traditional first.         Pop   2001-02-22     153.0         100
# ...
